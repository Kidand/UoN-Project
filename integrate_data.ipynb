# %%
import os
import shutil
import numpy as np

# 指定原始数据集和目标数据集的路径
src_dataset = "dataset_new"
dst_dataset = "dataset_total_new"

# 定义子数据集的顺序
order_of_datasets = ["1.5T-GE", "1.5T-Phillips", "3T-Achieva", "3T-Ingenia"]

# 在目标数据集目录下创建 imagesTr 和 labelsTr 文件夹
os.makedirs(os.path.join(dst_dataset, "imagesTr"), exist_ok=True)
os.makedirs(os.path.join(dst_dataset, "labelsTr"), exist_ok=True)

# 初始化计数器
counter = 1

# 初始化分层抽样的结果
stratified_samples = {i: [] for i in range(5)}  # 5 folds

# 按照指定的顺序遍历子数据集
for dataset in order_of_datasets:
    # 获取子数据集中的 imagesTr 和 labelsTr 路径
    images_path = os.path.join(src_dataset, dataset, "imagesTr")
    labels_path = os.path.join(src_dataset, dataset, "labelsTr")

    # 获取 imagesTr 和 labelsTr 中的文件列表
    images_files = sorted(os.listdir(images_path))
    labels_files = sorted(os.listdir(labels_path))

    # 为每个子数据集中的文件生成一个唯一的编号
    ids = np.arange(len(images_files)) + counter

    # 在每个子数据集中进行分层抽样
    fold_ids = np.mod(ids, 5)  # 5 folds

    # 根据抽样结果更新计数器和分层抽样的结果
    for i, (image_file, label_file) in enumerate(zip(images_files, labels_files)):
        # 指定目标文件名
        dst_image_file = f"data_{ids[i]:03}_0000.nii.gz"
        dst_label_file = f"data_{ids[i]:03}.nii.gz"

        # 使用 shutil.copy() 方法将文件复制到新的目录，并重命名
        shutil.copy(os.path.join(images_path, image_file), os.path.join(dst_dataset, "imagesTr", dst_image_file))
        shutil.copy(os.path.join(labels_path, label_file), os.path.join(dst_dataset, "labelsTr", dst_label_file))

        # 更新分层抽样的结果
        stratified_samples[fold_ids[i]].append((dst_image_file, dst_label_file))

    # 更新计数器
    counter += len(images_files)

# 输出分层抽样的结果
for i, samples in stratified_samples.items():
    print(f"Fold {i}:")
    for image_file, label_file in samples:
        print(f"    {image_file}, {label_file}")
# Out:
# Fold 0:
#     data_005_0000.nii.gz, data_005.nii.gz
#     data_010_0000.nii.gz, data_010.nii.gz
#     data_015_0000.nii.gz, data_015.nii.gz
#     data_020_0000.nii.gz, data_020.nii.gz
#     data_025_0000.nii.gz, data_025.nii.gz
#     data_030_0000.nii.gz, data_030.nii.gz
#     data_035_0000.nii.gz, data_035.nii.gz
#     data_040_0000.nii.gz, data_040.nii.gz
#     data_045_0000.nii.gz, data_045.nii.gz
#     data_050_0000.nii.gz, data_050.nii.gz
#     data_055_0000.nii.gz, data_055.nii.gz
#     data_060_0000.nii.gz, data_060.nii.gz
#     data_065_0000.nii.gz, data_065.nii.gz
#     data_070_0000.nii.gz, data_070.nii.gz
#     data_075_0000.nii.gz, data_075.nii.gz
#     data_080_0000.nii.gz, data_080.nii.gz
#     data_085_0000.nii.gz, data_085.nii.gz
#     data_090_0000.nii.gz, data_090.nii.gz
#     data_095_0000.nii.gz, data_095.nii.gz
#     data_100_0000.nii.gz, data_100.nii.gz
#     data_105_0000.nii.gz, data_105.nii.gz
#     data_110_0000.nii.gz, data_110.nii.gz
#     data_115_0000.nii.gz, data_115.nii.gz
#     data_120_0000.nii.gz, data_120.nii.gz
#     data_125_0000.nii.gz, data_125.nii.gz
#     data_130_0000.nii.gz, data_130.nii.gz
#     data_135_0000.nii.gz, data_135.nii.gz
#     data_140_0000.nii.gz, data_140.nii.gz
#     data_145_0000.nii.gz, data_145.nii.gz
#     data_150_0000.nii.gz, data_150.nii.gz
#     data_155_0000.nii.gz, data_155.nii.gz
#     data_160_0000.nii.gz, data_160.nii.gz
#     data_165_0000.nii.gz, data_165.nii.gz
#     data_170_0000.nii.gz, data_170.nii.gz
#     data_175_0000.nii.gz, data_175.nii.gz
#     data_180_0000.nii.gz, data_180.nii.gz
#     data_185_0000.nii.gz, data_185.nii.gz
#     data_190_0000.nii.gz, data_190.nii.gz
#     data_195_0000.nii.gz, data_195.nii.gz
#     data_200_0000.nii.gz, data_200.nii.gz
#     data_205_0000.nii.gz, data_205.nii.gz
#     data_210_0000.nii.gz, data_210.nii.gz
#     data_215_0000.nii.gz, data_215.nii.gz
#     data_220_0000.nii.gz, data_220.nii.gz
#     data_225_0000.nii.gz, data_225.nii.gz
#     data_230_0000.nii.gz, data_230.nii.gz
#     data_235_0000.nii.gz, data_235.nii.gz
#     data_240_0000.nii.gz, data_240.nii.gz
#     data_245_0000.nii.gz, data_245.nii.gz
#     data_250_0000.nii.gz, data_250.nii.gz
#     data_255_0000.nii.gz, data_255.nii.gz
#     data_260_0000.nii.gz, data_260.nii.gz
#     data_265_0000.nii.gz, data_265.nii.gz
#     data_270_0000.nii.gz, data_270.nii.gz
#     data_275_0000.nii.gz, data_275.nii.gz
#     data_280_0000.nii.gz, data_280.nii.gz
#     data_285_0000.nii.gz, data_285.nii.gz
#     data_290_0000.nii.gz, data_290.nii.gz
#     data_295_0000.nii.gz, data_295.nii.gz
# Fold 1:
#     data_001_0000.nii.gz, data_001.nii.gz
#     data_006_0000.nii.gz, data_006.nii.gz
#     data_011_0000.nii.gz, data_011.nii.gz
#     data_016_0000.nii.gz, data_016.nii.gz
#     data_021_0000.nii.gz, data_021.nii.gz
#     data_026_0000.nii.gz, data_026.nii.gz
#     data_031_0000.nii.gz, data_031.nii.gz
#     data_036_0000.nii.gz, data_036.nii.gz
#     data_041_0000.nii.gz, data_041.nii.gz
#     data_046_0000.nii.gz, data_046.nii.gz
#     data_051_0000.nii.gz, data_051.nii.gz
#     data_056_0000.nii.gz, data_056.nii.gz
#     data_061_0000.nii.gz, data_061.nii.gz
#     data_066_0000.nii.gz, data_066.nii.gz
#     data_071_0000.nii.gz, data_071.nii.gz
#     data_076_0000.nii.gz, data_076.nii.gz
#     data_081_0000.nii.gz, data_081.nii.gz
#     data_086_0000.nii.gz, data_086.nii.gz
#     data_091_0000.nii.gz, data_091.nii.gz
#     data_096_0000.nii.gz, data_096.nii.gz
#     data_101_0000.nii.gz, data_101.nii.gz
#     data_106_0000.nii.gz, data_106.nii.gz
#     data_111_0000.nii.gz, data_111.nii.gz
#     data_116_0000.nii.gz, data_116.nii.gz
#     data_121_0000.nii.gz, data_121.nii.gz
#     data_126_0000.nii.gz, data_126.nii.gz
#     data_131_0000.nii.gz, data_131.nii.gz
#     data_136_0000.nii.gz, data_136.nii.gz
#     data_141_0000.nii.gz, data_141.nii.gz
#     data_146_0000.nii.gz, data_146.nii.gz
#     data_151_0000.nii.gz, data_151.nii.gz
#     data_156_0000.nii.gz, data_156.nii.gz
#     data_161_0000.nii.gz, data_161.nii.gz
#     data_166_0000.nii.gz, data_166.nii.gz
#     data_171_0000.nii.gz, data_171.nii.gz
#     data_176_0000.nii.gz, data_176.nii.gz
#     data_181_0000.nii.gz, data_181.nii.gz
#     data_186_0000.nii.gz, data_186.nii.gz
#     data_191_0000.nii.gz, data_191.nii.gz
#     data_196_0000.nii.gz, data_196.nii.gz
#     data_201_0000.nii.gz, data_201.nii.gz
#     data_206_0000.nii.gz, data_206.nii.gz
#     data_211_0000.nii.gz, data_211.nii.gz
#     data_216_0000.nii.gz, data_216.nii.gz
#     data_221_0000.nii.gz, data_221.nii.gz
#     data_226_0000.nii.gz, data_226.nii.gz
#     data_231_0000.nii.gz, data_231.nii.gz
#     data_236_0000.nii.gz, data_236.nii.gz
#     data_241_0000.nii.gz, data_241.nii.gz
#     data_246_0000.nii.gz, data_246.nii.gz
#     data_251_0000.nii.gz, data_251.nii.gz
#     data_256_0000.nii.gz, data_256.nii.gz
#     data_261_0000.nii.gz, data_261.nii.gz
#     data_266_0000.nii.gz, data_266.nii.gz
#     data_271_0000.nii.gz, data_271.nii.gz
#     data_276_0000.nii.gz, data_276.nii.gz
#     data_281_0000.nii.gz, data_281.nii.gz
#     data_286_0000.nii.gz, data_286.nii.gz
#     data_291_0000.nii.gz, data_291.nii.gz
#     data_296_0000.nii.gz, data_296.nii.gz
# Fold 2:
#     data_002_0000.nii.gz, data_002.nii.gz
#     data_007_0000.nii.gz, data_007.nii.gz
#     data_012_0000.nii.gz, data_012.nii.gz
#     data_017_0000.nii.gz, data_017.nii.gz
#     data_022_0000.nii.gz, data_022.nii.gz
#     data_027_0000.nii.gz, data_027.nii.gz
#     data_032_0000.nii.gz, data_032.nii.gz
#     data_037_0000.nii.gz, data_037.nii.gz
#     data_042_0000.nii.gz, data_042.nii.gz
#     data_047_0000.nii.gz, data_047.nii.gz
#     data_052_0000.nii.gz, data_052.nii.gz
#     data_057_0000.nii.gz, data_057.nii.gz
#     data_062_0000.nii.gz, data_062.nii.gz
#     data_067_0000.nii.gz, data_067.nii.gz
#     data_072_0000.nii.gz, data_072.nii.gz
#     data_077_0000.nii.gz, data_077.nii.gz
#     data_082_0000.nii.gz, data_082.nii.gz
#     data_087_0000.nii.gz, data_087.nii.gz
#     data_092_0000.nii.gz, data_092.nii.gz
#     data_097_0000.nii.gz, data_097.nii.gz
#     data_102_0000.nii.gz, data_102.nii.gz
#     data_107_0000.nii.gz, data_107.nii.gz
#     data_112_0000.nii.gz, data_112.nii.gz
#     data_117_0000.nii.gz, data_117.nii.gz
#     data_122_0000.nii.gz, data_122.nii.gz
#     data_127_0000.nii.gz, data_127.nii.gz
#     data_132_0000.nii.gz, data_132.nii.gz
#     data_137_0000.nii.gz, data_137.nii.gz
#     data_142_0000.nii.gz, data_142.nii.gz
#     data_147_0000.nii.gz, data_147.nii.gz
#     data_152_0000.nii.gz, data_152.nii.gz
#     data_157_0000.nii.gz, data_157.nii.gz
#     data_162_0000.nii.gz, data_162.nii.gz
#     data_167_0000.nii.gz, data_167.nii.gz
#     data_172_0000.nii.gz, data_172.nii.gz
#     data_177_0000.nii.gz, data_177.nii.gz
#     data_182_0000.nii.gz, data_182.nii.gz
#     data_187_0000.nii.gz, data_187.nii.gz
#     data_192_0000.nii.gz, data_192.nii.gz
#     data_197_0000.nii.gz, data_197.nii.gz
#     data_202_0000.nii.gz, data_202.nii.gz
#     data_207_0000.nii.gz, data_207.nii.gz
#     data_212_0000.nii.gz, data_212.nii.gz
#     data_217_0000.nii.gz, data_217.nii.gz
#     data_222_0000.nii.gz, data_222.nii.gz
#     data_227_0000.nii.gz, data_227.nii.gz
#     data_232_0000.nii.gz, data_232.nii.gz
#     data_237_0000.nii.gz, data_237.nii.gz
#     data_242_0000.nii.gz, data_242.nii.gz
#     data_247_0000.nii.gz, data_247.nii.gz
#     data_252_0000.nii.gz, data_252.nii.gz
#     data_257_0000.nii.gz, data_257.nii.gz
#     data_262_0000.nii.gz, data_262.nii.gz
#     data_267_0000.nii.gz, data_267.nii.gz
#     data_272_0000.nii.gz, data_272.nii.gz
#     data_277_0000.nii.gz, data_277.nii.gz
#     data_282_0000.nii.gz, data_282.nii.gz
#     data_287_0000.nii.gz, data_287.nii.gz
#     data_292_0000.nii.gz, data_292.nii.gz
#     data_297_0000.nii.gz, data_297.nii.gz
# Fold 3:
#     data_003_0000.nii.gz, data_003.nii.gz
#     data_008_0000.nii.gz, data_008.nii.gz
#     data_013_0000.nii.gz, data_013.nii.gz
#     data_018_0000.nii.gz, data_018.nii.gz
#     data_023_0000.nii.gz, data_023.nii.gz
#     data_028_0000.nii.gz, data_028.nii.gz
#     data_033_0000.nii.gz, data_033.nii.gz
#     data_038_0000.nii.gz, data_038.nii.gz
#     data_043_0000.nii.gz, data_043.nii.gz
#     data_048_0000.nii.gz, data_048.nii.gz
#     data_053_0000.nii.gz, data_053.nii.gz
#     data_058_0000.nii.gz, data_058.nii.gz
#     data_063_0000.nii.gz, data_063.nii.gz
#     data_068_0000.nii.gz, data_068.nii.gz
#     data_073_0000.nii.gz, data_073.nii.gz
#     data_078_0000.nii.gz, data_078.nii.gz
#     data_083_0000.nii.gz, data_083.nii.gz
#     data_088_0000.nii.gz, data_088.nii.gz
#     data_093_0000.nii.gz, data_093.nii.gz
#     data_098_0000.nii.gz, data_098.nii.gz
#     data_103_0000.nii.gz, data_103.nii.gz
#     data_108_0000.nii.gz, data_108.nii.gz
#     data_113_0000.nii.gz, data_113.nii.gz
#     data_118_0000.nii.gz, data_118.nii.gz
#     data_123_0000.nii.gz, data_123.nii.gz
#     data_128_0000.nii.gz, data_128.nii.gz
#     data_133_0000.nii.gz, data_133.nii.gz
#     data_138_0000.nii.gz, data_138.nii.gz
#     data_143_0000.nii.gz, data_143.nii.gz
#     data_148_0000.nii.gz, data_148.nii.gz
#     data_153_0000.nii.gz, data_153.nii.gz
#     data_158_0000.nii.gz, data_158.nii.gz
#     data_163_0000.nii.gz, data_163.nii.gz
#     data_168_0000.nii.gz, data_168.nii.gz
#     data_173_0000.nii.gz, data_173.nii.gz
#     data_178_0000.nii.gz, data_178.nii.gz
#     data_183_0000.nii.gz, data_183.nii.gz
#     data_188_0000.nii.gz, data_188.nii.gz
#     data_193_0000.nii.gz, data_193.nii.gz
#     data_198_0000.nii.gz, data_198.nii.gz
#     data_203_0000.nii.gz, data_203.nii.gz
#     data_208_0000.nii.gz, data_208.nii.gz
#     data_213_0000.nii.gz, data_213.nii.gz
#     data_218_0000.nii.gz, data_218.nii.gz
#     data_223_0000.nii.gz, data_223.nii.gz
#     data_228_0000.nii.gz, data_228.nii.gz
#     data_233_0000.nii.gz, data_233.nii.gz
#     data_238_0000.nii.gz, data_238.nii.gz
#     data_243_0000.nii.gz, data_243.nii.gz
#     data_248_0000.nii.gz, data_248.nii.gz
#     data_253_0000.nii.gz, data_253.nii.gz
#     data_258_0000.nii.gz, data_258.nii.gz
#     data_263_0000.nii.gz, data_263.nii.gz
#     data_268_0000.nii.gz, data_268.nii.gz
#     data_273_0000.nii.gz, data_273.nii.gz
#     data_278_0000.nii.gz, data_278.nii.gz
#     data_283_0000.nii.gz, data_283.nii.gz
#     data_288_0000.nii.gz, data_288.nii.gz
#     data_293_0000.nii.gz, data_293.nii.gz
#     data_298_0000.nii.gz, data_298.nii.gz
# Fold 4:
#     data_004_0000.nii.gz, data_004.nii.gz
#     data_009_0000.nii.gz, data_009.nii.gz
#     data_014_0000.nii.gz, data_014.nii.gz
#     data_019_0000.nii.gz, data_019.nii.gz
#     data_024_0000.nii.gz, data_024.nii.gz
#     data_029_0000.nii.gz, data_029.nii.gz
#     data_034_0000.nii.gz, data_034.nii.gz
#     data_039_0000.nii.gz, data_039.nii.gz
#     data_044_0000.nii.gz, data_044.nii.gz
#     data_049_0000.nii.gz, data_049.nii.gz
#     data_054_0000.nii.gz, data_054.nii.gz
#     data_059_0000.nii.gz, data_059.nii.gz
#     data_064_0000.nii.gz, data_064.nii.gz
#     data_069_0000.nii.gz, data_069.nii.gz
#     data_074_0000.nii.gz, data_074.nii.gz
#     data_079_0000.nii.gz, data_079.nii.gz
#     data_084_0000.nii.gz, data_084.nii.gz
#     data_089_0000.nii.gz, data_089.nii.gz
#     data_094_0000.nii.gz, data_094.nii.gz
#     data_099_0000.nii.gz, data_099.nii.gz
#     data_104_0000.nii.gz, data_104.nii.gz
#     data_109_0000.nii.gz, data_109.nii.gz
#     data_114_0000.nii.gz, data_114.nii.gz
#     data_119_0000.nii.gz, data_119.nii.gz
#     data_124_0000.nii.gz, data_124.nii.gz
#     data_129_0000.nii.gz, data_129.nii.gz
#     data_134_0000.nii.gz, data_134.nii.gz
#     data_139_0000.nii.gz, data_139.nii.gz
#     data_144_0000.nii.gz, data_144.nii.gz
#     data_149_0000.nii.gz, data_149.nii.gz
#     data_154_0000.nii.gz, data_154.nii.gz
#     data_159_0000.nii.gz, data_159.nii.gz
#     data_164_0000.nii.gz, data_164.nii.gz
#     data_169_0000.nii.gz, data_169.nii.gz
#     data_174_0000.nii.gz, data_174.nii.gz
#     data_179_0000.nii.gz, data_179.nii.gz
#     data_184_0000.nii.gz, data_184.nii.gz
#     data_189_0000.nii.gz, data_189.nii.gz
#     data_194_0000.nii.gz, data_194.nii.gz
#     data_199_0000.nii.gz, data_199.nii.gz
#     data_204_0000.nii.gz, data_204.nii.gz
#     data_209_0000.nii.gz, data_209.nii.gz
#     data_214_0000.nii.gz, data_214.nii.gz
#     data_219_0000.nii.gz, data_219.nii.gz
#     data_224_0000.nii.gz, data_224.nii.gz
#     data_229_0000.nii.gz, data_229.nii.gz
#     data_234_0000.nii.gz, data_234.nii.gz
#     data_239_0000.nii.gz, data_239.nii.gz
#     data_244_0000.nii.gz, data_244.nii.gz
#     data_249_0000.nii.gz, data_249.nii.gz
#     data_254_0000.nii.gz, data_254.nii.gz
#     data_259_0000.nii.gz, data_259.nii.gz
#     data_264_0000.nii.gz, data_264.nii.gz
#     data_269_0000.nii.gz, data_269.nii.gz
#     data_274_0000.nii.gz, data_274.nii.gz
#     data_279_0000.nii.gz, data_279.nii.gz
#     data_284_0000.nii.gz, data_284.nii.gz
#     data_289_0000.nii.gz, data_289.nii.gz
#     data_294_0000.nii.gz, data_294.nii.gz

# %%
for i, samples in stratified_samples.items():
    print(f"Fold {i}:")
    # print samples size
    print(f"    {len(samples)}")
    for image_file, label_file in samples:
        print(f"    {image_file}, {label_file}")
# Out:
# Fold 0:
#     59
#     data_005_0000.nii.gz, data_005.nii.gz
#     data_010_0000.nii.gz, data_010.nii.gz
#     data_015_0000.nii.gz, data_015.nii.gz
#     data_020_0000.nii.gz, data_020.nii.gz
#     data_025_0000.nii.gz, data_025.nii.gz
#     data_030_0000.nii.gz, data_030.nii.gz
#     data_035_0000.nii.gz, data_035.nii.gz
#     data_040_0000.nii.gz, data_040.nii.gz
#     data_045_0000.nii.gz, data_045.nii.gz
#     data_050_0000.nii.gz, data_050.nii.gz
#     data_055_0000.nii.gz, data_055.nii.gz
#     data_060_0000.nii.gz, data_060.nii.gz
#     data_065_0000.nii.gz, data_065.nii.gz
#     data_070_0000.nii.gz, data_070.nii.gz
#     data_075_0000.nii.gz, data_075.nii.gz
#     data_080_0000.nii.gz, data_080.nii.gz
#     data_085_0000.nii.gz, data_085.nii.gz
#     data_090_0000.nii.gz, data_090.nii.gz
#     data_095_0000.nii.gz, data_095.nii.gz
#     data_100_0000.nii.gz, data_100.nii.gz
#     data_105_0000.nii.gz, data_105.nii.gz
#     data_110_0000.nii.gz, data_110.nii.gz
#     data_115_0000.nii.gz, data_115.nii.gz
#     data_120_0000.nii.gz, data_120.nii.gz
#     data_125_0000.nii.gz, data_125.nii.gz
#     data_130_0000.nii.gz, data_130.nii.gz
#     data_135_0000.nii.gz, data_135.nii.gz
#     data_140_0000.nii.gz, data_140.nii.gz
#     data_145_0000.nii.gz, data_145.nii.gz
#     data_150_0000.nii.gz, data_150.nii.gz
#     data_155_0000.nii.gz, data_155.nii.gz
#     data_160_0000.nii.gz, data_160.nii.gz
#     data_165_0000.nii.gz, data_165.nii.gz
#     data_170_0000.nii.gz, data_170.nii.gz
#     data_175_0000.nii.gz, data_175.nii.gz
#     data_180_0000.nii.gz, data_180.nii.gz
#     data_185_0000.nii.gz, data_185.nii.gz
#     data_190_0000.nii.gz, data_190.nii.gz
#     data_195_0000.nii.gz, data_195.nii.gz
#     data_200_0000.nii.gz, data_200.nii.gz
#     data_205_0000.nii.gz, data_205.nii.gz
#     data_210_0000.nii.gz, data_210.nii.gz
#     data_215_0000.nii.gz, data_215.nii.gz
#     data_220_0000.nii.gz, data_220.nii.gz
#     data_225_0000.nii.gz, data_225.nii.gz
#     data_230_0000.nii.gz, data_230.nii.gz
#     data_235_0000.nii.gz, data_235.nii.gz
#     data_240_0000.nii.gz, data_240.nii.gz
#     data_245_0000.nii.gz, data_245.nii.gz
#     data_250_0000.nii.gz, data_250.nii.gz
#     data_255_0000.nii.gz, data_255.nii.gz
#     data_260_0000.nii.gz, data_260.nii.gz
#     data_265_0000.nii.gz, data_265.nii.gz
#     data_270_0000.nii.gz, data_270.nii.gz
#     data_275_0000.nii.gz, data_275.nii.gz
#     data_280_0000.nii.gz, data_280.nii.gz
#     data_285_0000.nii.gz, data_285.nii.gz
#     data_290_0000.nii.gz, data_290.nii.gz
#     data_295_0000.nii.gz, data_295.nii.gz
# Fold 1:
#     60
#     data_001_0000.nii.gz, data_001.nii.gz
#     data_006_0000.nii.gz, data_006.nii.gz
#     data_011_0000.nii.gz, data_011.nii.gz
#     data_016_0000.nii.gz, data_016.nii.gz
#     data_021_0000.nii.gz, data_021.nii.gz
#     data_026_0000.nii.gz, data_026.nii.gz
#     data_031_0000.nii.gz, data_031.nii.gz
#     data_036_0000.nii.gz, data_036.nii.gz
#     data_041_0000.nii.gz, data_041.nii.gz
#     data_046_0000.nii.gz, data_046.nii.gz
#     data_051_0000.nii.gz, data_051.nii.gz
#     data_056_0000.nii.gz, data_056.nii.gz
#     data_061_0000.nii.gz, data_061.nii.gz
#     data_066_0000.nii.gz, data_066.nii.gz
#     data_071_0000.nii.gz, data_071.nii.gz
#     data_076_0000.nii.gz, data_076.nii.gz
#     data_081_0000.nii.gz, data_081.nii.gz
#     data_086_0000.nii.gz, data_086.nii.gz
#     data_091_0000.nii.gz, data_091.nii.gz
#     data_096_0000.nii.gz, data_096.nii.gz
#     data_101_0000.nii.gz, data_101.nii.gz
#     data_106_0000.nii.gz, data_106.nii.gz
#     data_111_0000.nii.gz, data_111.nii.gz
#     data_116_0000.nii.gz, data_116.nii.gz
#     data_121_0000.nii.gz, data_121.nii.gz
#     data_126_0000.nii.gz, data_126.nii.gz
#     data_131_0000.nii.gz, data_131.nii.gz
#     data_136_0000.nii.gz, data_136.nii.gz
#     data_141_0000.nii.gz, data_141.nii.gz
#     data_146_0000.nii.gz, data_146.nii.gz
#     data_151_0000.nii.gz, data_151.nii.gz
#     data_156_0000.nii.gz, data_156.nii.gz
#     data_161_0000.nii.gz, data_161.nii.gz
#     data_166_0000.nii.gz, data_166.nii.gz
#     data_171_0000.nii.gz, data_171.nii.gz
#     data_176_0000.nii.gz, data_176.nii.gz
#     data_181_0000.nii.gz, data_181.nii.gz
#     data_186_0000.nii.gz, data_186.nii.gz
#     data_191_0000.nii.gz, data_191.nii.gz
#     data_196_0000.nii.gz, data_196.nii.gz
#     data_201_0000.nii.gz, data_201.nii.gz
#     data_206_0000.nii.gz, data_206.nii.gz
#     data_211_0000.nii.gz, data_211.nii.gz
#     data_216_0000.nii.gz, data_216.nii.gz
#     data_221_0000.nii.gz, data_221.nii.gz
#     data_226_0000.nii.gz, data_226.nii.gz
#     data_231_0000.nii.gz, data_231.nii.gz
#     data_236_0000.nii.gz, data_236.nii.gz
#     data_241_0000.nii.gz, data_241.nii.gz
#     data_246_0000.nii.gz, data_246.nii.gz
#     data_251_0000.nii.gz, data_251.nii.gz
#     data_256_0000.nii.gz, data_256.nii.gz
#     data_261_0000.nii.gz, data_261.nii.gz
#     data_266_0000.nii.gz, data_266.nii.gz
#     data_271_0000.nii.gz, data_271.nii.gz
#     data_276_0000.nii.gz, data_276.nii.gz
#     data_281_0000.nii.gz, data_281.nii.gz
#     data_286_0000.nii.gz, data_286.nii.gz
#     data_291_0000.nii.gz, data_291.nii.gz
#     data_296_0000.nii.gz, data_296.nii.gz
# Fold 2:
#     60
#     data_002_0000.nii.gz, data_002.nii.gz
#     data_007_0000.nii.gz, data_007.nii.gz
#     data_012_0000.nii.gz, data_012.nii.gz
#     data_017_0000.nii.gz, data_017.nii.gz
#     data_022_0000.nii.gz, data_022.nii.gz
#     data_027_0000.nii.gz, data_027.nii.gz
#     data_032_0000.nii.gz, data_032.nii.gz
#     data_037_0000.nii.gz, data_037.nii.gz
#     data_042_0000.nii.gz, data_042.nii.gz
#     data_047_0000.nii.gz, data_047.nii.gz
#     data_052_0000.nii.gz, data_052.nii.gz
#     data_057_0000.nii.gz, data_057.nii.gz
#     data_062_0000.nii.gz, data_062.nii.gz
#     data_067_0000.nii.gz, data_067.nii.gz
#     data_072_0000.nii.gz, data_072.nii.gz
#     data_077_0000.nii.gz, data_077.nii.gz
#     data_082_0000.nii.gz, data_082.nii.gz
#     data_087_0000.nii.gz, data_087.nii.gz
#     data_092_0000.nii.gz, data_092.nii.gz
#     data_097_0000.nii.gz, data_097.nii.gz
#     data_102_0000.nii.gz, data_102.nii.gz
#     data_107_0000.nii.gz, data_107.nii.gz
#     data_112_0000.nii.gz, data_112.nii.gz
#     data_117_0000.nii.gz, data_117.nii.gz
#     data_122_0000.nii.gz, data_122.nii.gz
#     data_127_0000.nii.gz, data_127.nii.gz
#     data_132_0000.nii.gz, data_132.nii.gz
#     data_137_0000.nii.gz, data_137.nii.gz
#     data_142_0000.nii.gz, data_142.nii.gz
#     data_147_0000.nii.gz, data_147.nii.gz
#     data_152_0000.nii.gz, data_152.nii.gz
#     data_157_0000.nii.gz, data_157.nii.gz
#     data_162_0000.nii.gz, data_162.nii.gz
#     data_167_0000.nii.gz, data_167.nii.gz
#     data_172_0000.nii.gz, data_172.nii.gz
#     data_177_0000.nii.gz, data_177.nii.gz
#     data_182_0000.nii.gz, data_182.nii.gz
#     data_187_0000.nii.gz, data_187.nii.gz
#     data_192_0000.nii.gz, data_192.nii.gz
#     data_197_0000.nii.gz, data_197.nii.gz
#     data_202_0000.nii.gz, data_202.nii.gz
#     data_207_0000.nii.gz, data_207.nii.gz
#     data_212_0000.nii.gz, data_212.nii.gz
#     data_217_0000.nii.gz, data_217.nii.gz
#     data_222_0000.nii.gz, data_222.nii.gz
#     data_227_0000.nii.gz, data_227.nii.gz
#     data_232_0000.nii.gz, data_232.nii.gz
#     data_237_0000.nii.gz, data_237.nii.gz
#     data_242_0000.nii.gz, data_242.nii.gz
#     data_247_0000.nii.gz, data_247.nii.gz
#     data_252_0000.nii.gz, data_252.nii.gz
#     data_257_0000.nii.gz, data_257.nii.gz
#     data_262_0000.nii.gz, data_262.nii.gz
#     data_267_0000.nii.gz, data_267.nii.gz
#     data_272_0000.nii.gz, data_272.nii.gz
#     data_277_0000.nii.gz, data_277.nii.gz
#     data_282_0000.nii.gz, data_282.nii.gz
#     data_287_0000.nii.gz, data_287.nii.gz
#     data_292_0000.nii.gz, data_292.nii.gz
#     data_297_0000.nii.gz, data_297.nii.gz
# Fold 3:
#     60
#     data_003_0000.nii.gz, data_003.nii.gz
#     data_008_0000.nii.gz, data_008.nii.gz
#     data_013_0000.nii.gz, data_013.nii.gz
#     data_018_0000.nii.gz, data_018.nii.gz
#     data_023_0000.nii.gz, data_023.nii.gz
#     data_028_0000.nii.gz, data_028.nii.gz
#     data_033_0000.nii.gz, data_033.nii.gz
#     data_038_0000.nii.gz, data_038.nii.gz
#     data_043_0000.nii.gz, data_043.nii.gz
#     data_048_0000.nii.gz, data_048.nii.gz
#     data_053_0000.nii.gz, data_053.nii.gz
#     data_058_0000.nii.gz, data_058.nii.gz
#     data_063_0000.nii.gz, data_063.nii.gz
#     data_068_0000.nii.gz, data_068.nii.gz
#     data_073_0000.nii.gz, data_073.nii.gz
#     data_078_0000.nii.gz, data_078.nii.gz
#     data_083_0000.nii.gz, data_083.nii.gz
#     data_088_0000.nii.gz, data_088.nii.gz
#     data_093_0000.nii.gz, data_093.nii.gz
#     data_098_0000.nii.gz, data_098.nii.gz
#     data_103_0000.nii.gz, data_103.nii.gz
#     data_108_0000.nii.gz, data_108.nii.gz
#     data_113_0000.nii.gz, data_113.nii.gz
#     data_118_0000.nii.gz, data_118.nii.gz
#     data_123_0000.nii.gz, data_123.nii.gz
#     data_128_0000.nii.gz, data_128.nii.gz
#     data_133_0000.nii.gz, data_133.nii.gz
#     data_138_0000.nii.gz, data_138.nii.gz
#     data_143_0000.nii.gz, data_143.nii.gz
#     data_148_0000.nii.gz, data_148.nii.gz
#     data_153_0000.nii.gz, data_153.nii.gz
#     data_158_0000.nii.gz, data_158.nii.gz
#     data_163_0000.nii.gz, data_163.nii.gz
#     data_168_0000.nii.gz, data_168.nii.gz
#     data_173_0000.nii.gz, data_173.nii.gz
#     data_178_0000.nii.gz, data_178.nii.gz
#     data_183_0000.nii.gz, data_183.nii.gz
#     data_188_0000.nii.gz, data_188.nii.gz
#     data_193_0000.nii.gz, data_193.nii.gz
#     data_198_0000.nii.gz, data_198.nii.gz
#     data_203_0000.nii.gz, data_203.nii.gz
#     data_208_0000.nii.gz, data_208.nii.gz
#     data_213_0000.nii.gz, data_213.nii.gz
#     data_218_0000.nii.gz, data_218.nii.gz
#     data_223_0000.nii.gz, data_223.nii.gz
#     data_228_0000.nii.gz, data_228.nii.gz
#     data_233_0000.nii.gz, data_233.nii.gz
#     data_238_0000.nii.gz, data_238.nii.gz
#     data_243_0000.nii.gz, data_243.nii.gz
#     data_248_0000.nii.gz, data_248.nii.gz
#     data_253_0000.nii.gz, data_253.nii.gz
#     data_258_0000.nii.gz, data_258.nii.gz
#     data_263_0000.nii.gz, data_263.nii.gz
#     data_268_0000.nii.gz, data_268.nii.gz
#     data_273_0000.nii.gz, data_273.nii.gz
#     data_278_0000.nii.gz, data_278.nii.gz
#     data_283_0000.nii.gz, data_283.nii.gz
#     data_288_0000.nii.gz, data_288.nii.gz
#     data_293_0000.nii.gz, data_293.nii.gz
#     data_298_0000.nii.gz, data_298.nii.gz
# Fold 4:
#     59
#     data_004_0000.nii.gz, data_004.nii.gz
#     data_009_0000.nii.gz, data_009.nii.gz
#     data_014_0000.nii.gz, data_014.nii.gz
#     data_019_0000.nii.gz, data_019.nii.gz
#     data_024_0000.nii.gz, data_024.nii.gz
#     data_029_0000.nii.gz, data_029.nii.gz
#     data_034_0000.nii.gz, data_034.nii.gz
#     data_039_0000.nii.gz, data_039.nii.gz
#     data_044_0000.nii.gz, data_044.nii.gz
#     data_049_0000.nii.gz, data_049.nii.gz
#     data_054_0000.nii.gz, data_054.nii.gz
#     data_059_0000.nii.gz, data_059.nii.gz
#     data_064_0000.nii.gz, data_064.nii.gz
#     data_069_0000.nii.gz, data_069.nii.gz
#     data_074_0000.nii.gz, data_074.nii.gz
#     data_079_0000.nii.gz, data_079.nii.gz
#     data_084_0000.nii.gz, data_084.nii.gz
#     data_089_0000.nii.gz, data_089.nii.gz
#     data_094_0000.nii.gz, data_094.nii.gz
#     data_099_0000.nii.gz, data_099.nii.gz
#     data_104_0000.nii.gz, data_104.nii.gz
#     data_109_0000.nii.gz, data_109.nii.gz
#     data_114_0000.nii.gz, data_114.nii.gz
#     data_119_0000.nii.gz, data_119.nii.gz
#     data_124_0000.nii.gz, data_124.nii.gz
#     data_129_0000.nii.gz, data_129.nii.gz
#     data_134_0000.nii.gz, data_134.nii.gz
#     data_139_0000.nii.gz, data_139.nii.gz
#     data_144_0000.nii.gz, data_144.nii.gz
#     data_149_0000.nii.gz, data_149.nii.gz
#     data_154_0000.nii.gz, data_154.nii.gz
#     data_159_0000.nii.gz, data_159.nii.gz
#     data_164_0000.nii.gz, data_164.nii.gz
#     data_169_0000.nii.gz, data_169.nii.gz
#     data_174_0000.nii.gz, data_174.nii.gz
#     data_179_0000.nii.gz, data_179.nii.gz
#     data_184_0000.nii.gz, data_184.nii.gz
#     data_189_0000.nii.gz, data_189.nii.gz
#     data_194_0000.nii.gz, data_194.nii.gz
#     data_199_0000.nii.gz, data_199.nii.gz
#     data_204_0000.nii.gz, data_204.nii.gz
#     data_209_0000.nii.gz, data_209.nii.gz
#     data_214_0000.nii.gz, data_214.nii.gz
#     data_219_0000.nii.gz, data_219.nii.gz
#     data_224_0000.nii.gz, data_224.nii.gz
#     data_229_0000.nii.gz, data_229.nii.gz
#     data_234_0000.nii.gz, data_234.nii.gz
#     data_239_0000.nii.gz, data_239.nii.gz
#     data_244_0000.nii.gz, data_244.nii.gz
#     data_249_0000.nii.gz, data_249.nii.gz
#     data_254_0000.nii.gz, data_254.nii.gz
#     data_259_0000.nii.gz, data_259.nii.gz
#     data_264_0000.nii.gz, data_264.nii.gz
#     data_269_0000.nii.gz, data_269.nii.gz
#     data_274_0000.nii.gz, data_274.nii.gz
#     data_279_0000.nii.gz, data_279.nii.gz
#     data_284_0000.nii.gz, data_284.nii.gz
#     data_289_0000.nii.gz, data_289.nii.gz
#     data_294_0000.nii.gz, data_294.nii.gz

# %%
import json

# 初始化splits
splits = []

# 遍历分层抽样的结果
for i in range(5):
    # 获取当前fold的所有样本
    samples = stratified_samples[i]

    # 所有其他的fold将作为训练数据
    train_samples = [sample for j in range(5) if j != i for sample in stratified_samples[j]]

    # 提取训练集和验证集的标识符
    train_ids = [label_file.replace(".nii.gz", "") for _, label_file in train_samples]
    val_ids = [label_file.replace(".nii.gz", "") for _, label_file in samples]

    # 添加到splits
    splits.append({
        'train': train_ids,
        'val': val_ids,
    })

# 将splits保存到splits_final.json文件
with open('splits_final.json', 'w') as f:
    json.dump(splits, f, indent=4)

# %%
# deal with new dataset
import os
import shutil
import json

def split_files(json_data, source_folder="dataset_total_new/labelsTr", dest_folder="new_ss_val_folder"):
    """
    Split the nii.gz files from the source folder into five separate folders based on the JSON data.

    Parameters:
    - json_data: The JSON data containing the file names.
    - source_folder: The folder containing the original nii.gz files.
    - dest_folder: The base folder where the split files will be stored.
    """

    # Ensure the destination folder exists
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)

    # Loop through the JSON data to split the files
    for idx, entry in enumerate(json_data):
        subfolder_name = f"split_{idx + 1}"
        subfolder_path = os.path.join(dest_folder, subfolder_name)

        # Ensure the subfolder exists
        if not os.path.exists(subfolder_path):
            os.makedirs(subfolder_path)

        # Copy the files to the respective subfolder
        for file_name in entry['val']:
            source_file_path = os.path.join(source_folder, file_name + ".nii.gz")
            dest_file_path = os.path.join(subfolder_path, file_name + ".nii.gz")

            if os.path.exists(source_file_path):
                shutil.copy(source_file_path, dest_file_path)
            else:
                print(f"File {source_file_path} not found!")

# Example usage
with open('val_group.json', 'r') as f:
    data = json.load(f)
    split_files(data)
